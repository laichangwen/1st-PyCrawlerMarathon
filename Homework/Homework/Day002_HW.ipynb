# %% [markdown]
# # Python 下載CSV檔案與解析
#
#
# * 了解 csv 檔案格式與內容
# * 能夠利用套件存取 csv 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「CSV Reader」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 取出班次一的每一個時間
#     2. 將班次一的每一個時間用一種資料型態保存
#     3. 將班次一到五與其所有時間用一種資料型態個別保存

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「CSV Reader」讀出來的內容有什麼差異

# %%
import urllib.request
import os
import csv

path = './Data'
res = "http://opendata.hccg.gov.tw/dataset/432257df-491f-4875-8b56-dd814aee5d7b/resource/de014c8b-9b75-4152-9fc6-f0d499cefbe4/download/20150305140446074.csv"
urllib.request.urlretrieve(res, os.path.join(path, 'example_file_io.csv'))

with open('./data/example.csv', newline='', encoding = 'utf-8') as csvfile:
    f = csv.reader(csvfile)
    for row in f:
        print(''.join(row))
# Out:
# ﻿序號路線編號起訖站平/假日站名班次1班次2班次3班次4班次5班次6班次7班次8班次9班次10班次11是否單邊停靠
# 151香山區公所—火車站（先經中山路）平日香山區公所06:3007:5009:1010:3012:0013:2014:4016:1018:1019:4021:10否
# 251香山區公所—火車站（先經中山路）平日香山國小06:3207:5209:1210:3212:0213:2214:4216:1218:1219:4221:12否
# 351香山區公所—火車站（先經中山路）平日聖德宮06:3307:5309:1310:3312:0313:2314:4316:1318:1319:4321:13否
# 451香山區公所—火車站（先經中山路）平日頂埔社區06:3407:5509:1510:3512:0513:2414:4516:1518:1519:4521:15否
# 551香山區公所—火車站（先經中山路）平日大鵬新城06:3607:5709:1710:3712:0713:2614:4716:1718:1719:4721:17單邊停靠
# 651香山區公所—火車站（先經中山路）平日台貿四村06:3807:5909:1910:3912:0913:2814:4916:1918:1919:4921:19單邊停靠
# 751香山區公所—火車站（先經中山路）平日天公壇06:3908:0109:2110:4112:1113:2914:5116:2118:2119:5121:21單邊停靠
# 851香山區公所—火車站（先經中山路）平日中山路06:4108:0309:2310:4312:1313:3114:5316:2318:2319:5321:23單邊停靠
# 951香山區公所—火車站（先經中山路）平日西門口06:4208:0409:2410:4412:1413:3214:5416:2418:2419:5421:24單邊停靠
# 1051香山區公所—火車站（先經中山路）平日西門市場06:4308:0509:2510:4512:1513:3314:5516:2518:2519:5521:25單邊停靠
# ...

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 取出班次一的每一個時間
# 2. 將班次一的每一個時間用一種資料型態保存
# 3. 將班次一到五與其所有時間用一種資料型態個別保存

# %%
import csv
# 開啟 CSV 檔案
with open('./data/example.csv', newline='', encoding = 'utf-8') as csvfile:
    # 讀取 CSV 檔案內容
    rows = csv.reader(csvfile)
    # 以迴圈輸出每一列
    for row in rows:
        print(row)
# Out:
# ['\ufeff序號', '路線編號', '起訖站', '平/假日', '站名', '班次1', '班次2', '班次3', '班次4', '班次5', '班次6', '班次7', '班次8', '班次9', '班次10', '班次11', '是否單邊停靠']
# ['1', '51', '香山區公所—火車站（先經中山路）', '平日', '香山區公所', '06:30', '07:50', '09:10', '10:30', '12:00', '13:20', '14:40', '16:10', '18:10', '19:40', '21:10', '否']
# ['2', '51', '香山區公所—火車站（先經中山路）', '平日', '香山國小', '06:32', '07:52', '09:12', '10:32', '12:02', '13:22', '14:42', '16:12', '18:12', '19:42', '21:12', '否']
# ['3', '51', '香山區公所—火車站（先經中山路）', '平日', '聖德宮', '06:33', '07:53', '09:13', '10:33', '12:03', '13:23', '14:43', '16:13', '18:13', '19:43', '21:13', '否']
# ['4', '51', '香山區公所—火車站（先經中山路）', '平日', '頂埔社區', '06:34', '07:55', '09:15', '10:35', '12:05', '13:24', '14:45', '16:15', '18:15', '19:45', '21:15', '否']
# ['5', '51', '香山區公所—火車站（先經中山路）', '平日', '大鵬新城', '06:36', '07:57', '09:17', '10:37', '12:07', '13:26', '14:47', '16:17', '18:17', '19:47', '21:17', '單邊停靠']
# ...

# %%
# 1. 取出班次一的每一個時間
import csv
# 開啟 CSV 檔案
with open('./Data/example.csv', newline='', encoding = 'utf-8') as csvfile:
    # 讀取 CSV 檔案內容
    rows = csv.DictReader(csvfile)
    # 以迴圈輸出每一列
    for row in rows:
        print(row['班次1'])
# Out:
# 06:30
# 06:32
# 06:33
# 06:34
# 06:36
# 06:38
# 06:39
# 06:41
# 06:42
# 06:43
# 06:44
# 06:45
# 06:46
# 06:47
# 06:48
# 06:49
# 06:50
# 06:51
# 06:53
# 06:55
# 06:57
# 06:58
# 07:00
# 07:01
# 07:03
# 07:05
# 07:07
# 07:09
# 07:10
# 07:12
# 07:14
# 07:16
# 07:18
# 07:20
# 07:21
# 07:23
# 07:24
# 07:25
# 07:00
# 07:02
# 07:03
# 07:04
# 07:06
# 07:08
# 07:09
# 07:11
# 07:12
# 07:13
# 07:14
# 07:15
# 07:16
# 07:17
# 07:18
# 07:19
# 07:20
# 07:21
# 07:23
# 07:25
# 07:27
# 07:28
# 07:30
# 07:31
# 07:33
# 07:35
# 07:37
# 07:39
# 07:40
# 07:42
# 07:44
# 07:46
# 07:48
# 07:49
# 07:51
# 07:53
# 07:54
# 07:55
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2a83b9eae916> in <module>
#       8     for row in rows:
#       9         print(row['班次1'])
# ---> 10     print(rows_N = csv.reader(csvfile.readlines()[:N]))
#
# NameError: name 'N' is not defined

# %%
# 2. 將班次一的每一個時間用一種資料型態保存
import csv
time_list = []
with open('./Data/example.csv', newline='', encoding = 'utf-8') as infile:
    with open('./Data/time_1.csv', 'w', newline='', encoding = encoding) as outfile:
    
        writer = csv.writer(outfile, delimiter=' ', quotechar='|')

        time_list.append('班次1')
        for row in csv.DictReader(infile):
            time_list.append(row['班次1'])
        writer.writerows(time_list)
# Out:
# ['班次1', '06:30', '06:32', '06:33', '06:34', '06:36', '06:38', '06:39', '06:41', '06:42', '06:43', '06:44', '06:45', '06:46', '06:47', '06:48', '06:49', '06:50', '06:51', '06:53', '06:55', '06:57', '06:58', '07:00', '07:01', '07:03', '07:05', '07:07', '07:09', '07:10', '07:12', '07:14', '07:16', '07:18', '07:20', '07:21', '07:23', '07:24', '07:25', '07:00', '07:02', '07:03', '07:04', '07:06', '07:08', '07:09', '07:11', '07:12', '07:13', '07:14', '07:15', '07:16', '07:17', '07:18', '07:19', '07:20', '07:21', '07:23', '07:25', '07:27', '07:28', '07:30', '07:31', '07:33', '07:35', '07:37', '07:39', '07:40', '07:42', '07:44', '07:46', '07:48', '07:49', '07:51', '07:53', '07:54', '07:55']

# %%
# 3. 將班次一到五與其所有時間用一種資料型態個別保存

import csv
time_list_0 = ['班次1']
time_list_1 = ['班次2']
time_list_2 = ['班次3']
time_list_3 = ['班次4']
time_list_4 = ['班次5']
filenames = ['班次1', '班次2', '班次3', '班次4', '班次5']
with open('./Data/example.csv', newline='', encoding = 'utf-8') as infile:
    with open('./Data/time_2.csv', 'w', newline='', encoding = encoding) as outfile:
    
        writer = csv.writer(outfile, delimiter=' ', quotechar='|')


        for row in csv.DictReader(infile):
            time_list_0.append(row[time_list_0[0]])    
            time_list_1.append(row[time_list_1[0]])
            time_list_2.append(row[time_list_2[0]])
            time_list_3.append(row[time_list_3[0]])
            time_list_4.append(row[time_list_4[0]])
        rows = zip(time_list_0, time_list_1, time_list_2, time_list_3, time_list_4)
        writer.writerows(rows)
